# %% [markdown]
# # Helper Functions Demonstration
#
# This notebook demonstrates the use of the helper functions in `utils.py`: `populate_shared_ride_lengths()` and `create_route_map()`.

# %% [markdown]
# Load packages and functions

# %%
import numpy as np
from utils import populate_shared_ride_lengths, plot_riders, create_route_map, IIJJ, IJIJ, IJJI, JIJI, JIIJ

# %% [markdown]
# Load the coordinates of the pickup and dropoff locations of two riders.

# %%
# the OD of rider i
origin_i = (41.920126404, -87.7607889112)  # (lat, lon) of the pickup location
destination_i = (41.9350581526, -87.7376199977)  # (lat, lon) of the dropoff location

# the OD of rider j
origin_j = (41.9272609555, -87.7655016086)  # (lat, lon) of the pickup location
destination_j = (41.9243470769, -87.7347397536)  # (lat, lon) of the dropoff location

# %% [markdown]
# Visualize the origin-destination pairs on a map.

# %%
# create a list of riders, each represented as a tuple of (origin_lat, origin_lon, dest_lat, dest_lon) for a rider type.
riders = [(origin_i[0], origin_i[1], destination_i[0], destination_i[1]),
            (origin_j[0], origin_j[1], destination_j[0], destination_j[1])]
# plot the riders on a map
plot_riders(riders)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f622b23af7bf18b98672b1098a2841c6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f622b23af7bf18b98672b1098a2841c6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f622b23af7bf18b98672b1098a2841c6 = L.map(
#                 &quot;map_f622b23af7bf18b98672b1098a2841c6&quot;,
#                 {
#                     center: [41.92669814725, -87.749662567775],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c8887643904c7f9203037fd8ea010f0f = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c8887643904c7f9203037fd8ea010f0f.addTo(map_f622b23af7bf18b98672b1098a2841c6);
#
#
#             var marker_a00e03c36429ecfedd1042401d2c1858 = L.marker(
#                 [41.920126404, -87.7607889112],
#                 {
# }
#             ).addTo(map_f622b23af7bf18b98672b1098a2841c6);
#
#
#             var icon_34c98bb85810f5144a787aef5d3de00a = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;home&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#             marker_a00e03c36429ecfedd1042401d2c1858.bindTooltip(
#                 `&lt;div&gt;
#                      Rider 0 Pickup
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_a00e03c36429ecfedd1042401d2c1858.setIcon(icon_34c98bb85810f5144a787aef5d3de00a);
#
#
#             var marker_552b39261543857c361ea3f36220700d = L.marker(
#                 [41.9350581526, -87.7376199977],
#                 {
# }
#             ).addTo(map_f622b23af7bf18b98672b1098a2841c6);
#
#
#             var icon_bf6edf305ae1443031dab710715a4ead = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;flag&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#             marker_552b39261543857c361ea3f36220700d.bindTooltip(
#                 `&lt;div&gt;
#                      Rider 0 Dropoff
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_552b39261543857c361ea3f36220700d.setIcon(icon_bf6edf305ae1443031dab710715a4ead);
#
#
#             var poly_line_fdb3ee1c6068e7810cd793c678395c92 = L.polyline(
#                 [[41.920126404, -87.7607889112], [41.9350581526, -87.7376199977]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_f622b23af7bf18b98672b1098a2841c6);
#
#
#             poly_line_fdb3ee1c6068e7810cd793c678395c92.bindTooltip(
#                 `&lt;div&gt;
#                      Rider 0 Route
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_0debcaedc1021db12bb12474ac940c15 = L.marker(
#                 [41.920126404, -87.7607889112],
#                 {
# }
#             ).addTo(map_f622b23af7bf18b98672b1098a2841c6);
#
#
#             var div_icon_6dcc77507b0887e6d6e20dc1590b47a2 = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\u0027\n        display: inline-block;\n        font-size: 13px;\n        color: white;\n        background-color: gray;\n        border: 1px solid white;\n        padding: 3px 8px;\n        border-radius: 5px;\n        max-width: 150x;\n        white-space: nowrap;\n        box-sizing: border-box;\n        opacity: 0.8;\n    \u0027\u003e\u003cb\u003eRider 0 Pickup\u003c/b\u003e\u003c/div\u003e&quot;,
#   &quot;className&quot;: &quot;empty&quot;,
# });
#
#
#                 marker_0debcaedc1021db12bb12474ac940c15.setIcon(div_icon_6dcc77507b0887e6d6e20dc1590b47a2);
#
#
#             var

# %% [markdown]
# Calculate the shortest path of the shared ride between the two riders, using the function `populate_shared_ride_lengths()`. (You may not need all five returned results, but they are provided for your convenience.)

# %%
# calculate the shared ride lengths
(
    trip_length,
    shared_length,
    i_solo_length,
    j_solo_length,
    trip_order,
) = populate_shared_ride_lengths(origin_i, destination_i, origin_j, destination_j)

# check the results: the trip length should be the sum of the shared length and the two solo lengths
assert np.isclose(trip_length, shared_length + i_solo_length + j_solo_length)

# explain the results
print("The shortest length of the shared trip between the two riders is: {:.3f} miles.".format(trip_length))
print("The trip length when both riders are in the vehicle: {:.3f} miles".format(shared_length))
print("The trip length when only rider i is in the vehicle: {:.3f} miles".format(i_solo_length))
print("The trip length when only rider j is in the vehicle: {:.3f} miles".format(j_solo_length))

if trip_order == IIJJ:
    print("The trip order is: pick up rider i - drop off rider i - pick up rider j - drop off rider j")
elif trip_order == IJIJ:
    print("The trip order is: pick up rider i - pick up rider j - drop off rider i - drop off rider j")
elif trip_order == IJJI:
    print("The trip order is: pick up rider i - pick up rider j - drop off rider j - drop off rider i")
elif trip_order == JIJI:
    print("The trip order is: pick up rider j - pick up rider i - drop off rider j - drop off rider i")
elif trip_order == JIIJ:
    print("The trip order is: pick up rider j - pick up rider i - drop off rider i - drop off rider j")
# Out:
# The shortest length of the shared trip between the two riders is: 2.675 miles.
# The trip length when both riders are in the vehicle: 1.371 miles
# The trip length when only rider i is in the vehicle: 0.755 miles
# The trip length when only rider j is in the vehicle: 0.549 miles
# The trip order is: pick up rider j - pick up rider i - drop off rider j - drop off rider i

# %% [markdown]
# Plot the routing map of the shared ride, using the function `create_route_map()`.

# %%
create_route_map(origin_i, destination_i, origin_j, destination_j, trip_order)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_65fe082aef7904956b1ca9c3105dc2fc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_65fe082aef7904956b1ca9c3105dc2fc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_65fe082aef7904956b1ca9c3105dc2fc = L.map(
#                 &quot;map_65fe082aef7904956b1ca9c3105dc2fc&quot;,
#                 {
#                     center: [41.92369367975, -87.7631452599],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2ebd9b44fcacd40fc56b2408cdaaf077 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2ebd9b44fcacd40fc56b2408cdaaf077.addTo(map_65fe082aef7904956b1ca9c3105dc2fc);
#
#
#             var marker_3f95903832a45be333ca8da60d27d7c3 = L.marker(
#                 [41.920126404, -87.7607889112],
#                 {
# }
#             ).addTo(map_65fe082aef7904956b1ca9c3105dc2fc);
#
#
#             var icon_873482b1eb99e3c973971bace6528556 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;home&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#                 marker_3f95903832a45be333ca8da60d27d7c3.setIcon(icon_873482b1eb99e3c973971bace6528556);
#
#
#             var marker_d5ce857dcbe4ea02dc40f7861729e6ae = L.marker(
#                 [41.920126404, -87.7607889112],
#                 {
# }
#             ).addTo(map_65fe082aef7904956b1ca9c3105dc2fc);
#
#
#             var div_icon_503e8fc1d04d6f5704e699c513a7b7b2 = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\u0027\n        display: inline-block;\n        font-size: 13px;\n        color: white;\n        background-color: gray;\n        border: 1px solid white;\n        padding: 3px 8px;\n        border-radius: 5px;\n        max-width: 150x;\n        white-space: nowrap;\n        box-sizing: border-box;\n        opacity: 0.8;\n    \u0027\u003e\u003cb\u003eRider 0 Pickup\u003c/b\u003e\u003c/div\u003e&quot;,
#   &quot;className&quot;: &quot;empty&quot;,
# });
#
#
#                 marker_d5ce857dcbe4ea02dc40f7861729e6ae.setIcon(div_icon_503e8fc1d04d6f5704e699c513a7b7b2);
#
#
#             var marker_78b5f031ecf6fcbf4534d0bf7be45176 = L.marker(
#                 [41.9350581526, -87.7376199977],
#                 {
# }
#             ).addTo(map_65fe082aef7904956b1ca9c3105dc2fc);
#
#
#             var icon_88cf5511bfab4cb048b8ff482a6165ff = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;flag&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#                 marker_78b5f031ecf6fcbf4534d0bf7be45176.setIcon(icon_88cf5511bfab4cb048b8ff482a6165ff);
#
#
#             var marker_975776690a64a5429ec686ad4a97e1f1 = L.marker(
#                 [41.9350581526, -87.7376199977],
#                 {
# }
#             ).addTo(map_65fe082aef7904956b1ca9c3105dc2fc);
#
#
#             var div_icon_a2ffc87a2b445b9b18ff40d517002b2f = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\u0027\n        display: inline-block;\n        font-size: 13px;\n        color: white;\n        background-color: gray;\n        border: 1px solid white;\n        padding: 3px 8px;\n        border-radius: 5px;\n        max-width: 150x;\n        white-space: nowrap;\n        box-sizing: border-box;\n        opacity: 0.8;\n    \u0027\u003e\u003cb\u003eRider 0 Dropoff\u003c/b\u003e\u003c/div\u003e&quot;,
#   &quot;className&quot;: &quot;empty&quot;,
# });
#
#
#                 marker_975776690a64a5429ec686ad4a97e1f1.setIcon(div_icon_a2ffc87a2b445b9b18ff40d517002b2f);
#
#
#             var marker_0857b379f1f1226df021cf736f360604 = L.marker(
#                 [41.9272609555, -87.7655016086],
#                 {
# }
#             ).addTo(map_65fe082aef7904956b1ca9c3105dc2fc);
#
#
#             var icon_2331a4e9ed8cdb57b2cf60bd2ec9db7a = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;home&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
